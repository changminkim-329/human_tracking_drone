# %% [markdown]
# # YOLO(You Only Look Once)
# - grid-wise하게 detection하는 것이 일종의 constrainsts가 되어 각가의. detector가 특화 될 수 있으면, 이것이 detection에서 굉장히 중ㅇㅛ한 부분이라는 것.

# %%
 YOLO, SSD, SqueezeDet, and DetectNet.

# %% [markdown]
# ## Object Detection
# - Object detection은 classification보다 더 많이 발전 되다.
# - object detection 모델은 bounding boxes(Localization)과 classification을 예측하는 것이다.
#     - 두가지를 동시에 하면 one_stage_object_detection이라고 함
#     - 각각 한가지씩 하면 two_stage_object_detection이라고 함
# - 보통 매우 많은 bounding box들을 친다.
# - 각각의 bounding box는 confidence score을 가진다.->confidence score는 그 box가 정말로 물체를 포함할 거 같은 가에 대한 점수이다.
# - 마지막 후처리과정에서 특정 threshold 값 아래의 confidence score을 가진 box들을 없애준다(non-maximum suppression)
#
# - One of the problems you’ll encounter is that a training image can have anywhere from zero to dozens of objects in them,
#
# - loss function
#     - cross-entropy : claasification
#     - mean-squared-error : localization
#
# - IOU
#     - Intersection-Over-Union
#     - 교집합 영역 넓이 / 합집합 영역 넓이

# %% [markdown]
#  box confidence score는 box가 객체를 포함하고 있을 가능성(objectness)과 boundary box가 얼마나 정확한지를 반영
#  ![](https://miro.medium.com/max/700/1*0IPktA65WxOBfP_ULQWcmw.png)

# %% [markdown]
# It’s much harder for a machine learning model to learn about images if we only use plain FC layers. The constraints imposed upon the convolutional layer — it looks only at a few pixels at a time, and the connections share the same weights — help the model to extract knowledge from images. We use these constraints to remove degrees of freedom and to guide the model into learning what we want it to learn.
#
# Likewise, the grid forces the model to learn object detectors that specialize in specific locations.

# %% [markdown]
# - ground-truth boxes = annotation
# - class probabilities = classification_num
# - confidence = object-ness

# %% [markdown]
# ### IOU 구현해보기

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a_image = np.ones((150,150))
b_image = np.ones((150,150))

frame = np.zeros((300,300))
random_w = np.random.randint(0,150)
random_h = np.random.randint(0,150)
ax_min = random_w
ax_max = random_w+150
ay_min = random_h
ay_max = random_h+150

frame[ay_min:ay_max,ax_min:ax_max] +=a_image

random_w = np.random.randint(0,150)
random_h = np.random.randint(0,150)
bx_min = random_w
bx_max = random_w+150
by_min = random_h
by_max = random_h+150

frame[by_min:by_max,bx_min:bx_max] += b_image
copy_frame = np.zeros((300,300))
iou = 0
if(ax_min < bx_min):
    if(ay_min < by_min):
        if(bx_min < ax_max and by_min < ay_max):
            print('1')
            copy_frame[by_min:ay_max,bx_min:ax_max] = np.ones((ay_max-by_min,ax_max-bx_min))
            
            intersection = (ay_max-by_min)*(ax_max-bx_min)
            union = 150*150 + 150*150 - intersection
            iou = intersection/union
            
    elif(ay_min > by_min):
        if(bx_min < ax_max and ay_min < by_max):
            print('2')
            copy_frame[ay_min:by_max,bx_min:ax_max] = np.ones((by_max-ay_min,ax_max-bx_min))
            
            intersection = (by_max-ay_min)*(ax_max-bx_min)
            union = 150*150 + 150*150 - intersection
            iou = intersection/union

elif(ax_min > bx_min):
    if(ay_min < by_min):
        if(ax_min < bx_max and by_min < ay_max):
            print('3')
            copy_frame[by_min:ay_max,ax_min:bx_max] = np.ones((ay_max-by_min,bx_max-ax_min))
            
            intersection = (ay_max-by_min)*(bx_max-ax_min)
            union = 150*150 + 150*150 - intersection
            iou = intersection/union
            
    elif(ay_min > by_min):
        if(ax_min < bx_max and ay_min < by_max):
            print('4')
            copy_frame[ay_min:by_max,ax_min:bx_max] = np.ones((by_max-ay_min,bx_max-ax_min))
            
            intersection = (by_max-ay_min)*(bx_max-ax_min)
            union = 150*150 + 150*150 - intersection
            iou = intersection/union

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("intersection")
plt.imshow(copy_frame)
plt.subplot(1,2,2)
plt.title("intersection")
plt.title("iou:"+str(iou))
plt.imshow(frame)
plt.show()
# Out:
# 1

# %%
def get_iou(b1, b2, epsilon=1e-5):
    """ Given two boxes `a` and `b` defined as a list of four numbers:
            [center_x,center_y,width,height]
 
    Returns:
        (float) The Intersect of Union score.
    """
    
    # The Area Of Intersect
    intersect_width  = min(b1[2],b2[2])
    
    intersect_height = min(b1[3],b2[3])
    
    
    intersect_area = intersect_width * intersect_height
    
    # The Area Of Union
    b1_area = b1[2] * b1[3]
    b2_area = b2[2] * b2[3]
    
    union_area = b1_area + b2_area - intersect_area
    
 
    # Intersection Of Union
    iou = intersect_area / (union_area+epsilon)
    return iou

# %% [markdown]
# ### Machine is Stupid
# regresion으로 하나의 bounding box을 예측하는 것은 좋은 결과를 준다. 하지만 분류의 문제와 같이, 이미지에 2개 이상의 물체가 있으면 잘 동작하지 않는다. 그 이유는 기존 4개의 regression(sigmoid)한 값을 출력하는 것은 하나의 bounding box을 예측하는 것이다. 그래서 만약 2개 이상의 관심 대상이 있을 때 둘 중 하나를 골라야 된다. 하지만, 모델은 (생각이 없어서) 실제로 둘 중 하나를 고르지 않고 밑에 그림처럼 중간의 어느 위치가 될 것이다.
# ![](https://machinethink.net/images/object-detection/localization-1box-bad.jpg)
#
# 그럼 두개 이상의 bounding box 예측기를 추가하면 어떨까? 잘 실행되어 두 개이상의 물체를 잘 bounding해줄까? 그렇지 않다. 밑에 처럼 중앙에 bounding box들이 처질 것이다. 왜 그런 것일까? 왜냐하면 모델은 어떤 바운딩 박스가 어떤 물체에 할당 되어야 되는 지 알지 못한다. 각각의 예측기는 모든 물체가 가능한 위치를 예측하려고 한다. 그래서 모델은 중간에 놓려고 할 것이다. 사실상 모델에게 무리한 요구 인것이다. **각각의 예측기는 하나를 대상으로 bounding 치려고 하지 않고 두 물체에 대해서 bounding 치려고 할 것이다. 그래서 중앙에 놓이게 된다.** 문제를 해결하기 위해서 **각각의 예측기가 이미지의 특정한 위치에 전문화(고정) 되도록 학습할 필요가 있다.**
# ![](https://machinethink.net/images/object-detection/localization-2box-bad.jpg)

# %% [markdown]
# 보통 multi-classification을 할때는 softmax를 하지만, detection에서는 boundingbox와 독립적으로 수행되기 때문에 sigmoid를 사용한다.

# %% [markdown]
# confidence score: 예측된 bounding box가 진짜 물체를 포함하고 있는지를 나타냄(0~1), object-ness라고도 함, 오직 물체가 있는지 없는지만 말해줌, object연산에 사용됨(iou)

# %% [markdown]
# ### Constraints are good
# 13x13 grid는 일종의 부분적 제약(spatial constraint)이다. 이러한 제약은 모델이 bouding box를 보다 쉽게 예측하도록 한다. convolution layer도 그자체로 fully-connected layer의 제약 버전이다. fully-connected layer는 모든 픽셀에 대해서 weight를 취하지만 convolution layer는 특정 맵만 사용하여 한 channel에 대해서 weight를 공유한다(contraint).**constraints(제약)은 모델이 이미지로 부터 지식을 추출하도록 돕는다.** 여기서 **13x13 grid constraints는 자유로움의 정도를 제거하고 우리가 원하는 모델이 되도록 학습 되게 한다.**

# %% [markdown]
# ### anchors
# anchor는 물체의 형태를 제약하는 것이다. 한 cell에서 하나의 detector만으로 어떤 형태(bouding box)을 가질 수 있는 물체를 예측하는 건 매우 어렵다.
# - anchor들은 cell안에 있는 detector들이 각각 특정 오브젝트 shape에 대해서 전문화 되도록 한다.
# - 대략 평균 anchor 리스트
# ![](https://machinethink.net/images/object-detection/anchors.png)
# - 위의 그림처럼 각각의 anchor box들은 사전에 골라진다. -> 그것들은 훈련하는 동안 불변한다.
# - bias라고도 함 -> anchor들의 값은 detector이 물체의 특정한 shape를 예측하도록 편중(biased)되어진다.
# - anchor 리스트는 모든 train의 bounding box(annotation)에 대해서 **k-mean-clustering**으로 구현되어 고정된다.
#
#
# - anchor박스를 많이 할수록 iou가 1에 가까워진다. 밑에 그림을 참조
# ![](https://machinethink.net/images/object-detection/number-of-centroids.png)

# %% [markdown]
# ### K mean Clustering
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile4.uf.tistory.com%2Fimage%2F9909223C5AC63A891F05F1)
# - 데이터를 입력받아 이를 소수의 그룹으로 묶는 알고리즘
# - 비지도 학습(label이 없는 데이터)
# - loss_function
# $${argmin_{r,c}\sum^N_{n=1}\sum^K_{k=1}r_{nk}{||x_n - c_k||}^2}$$

# %% [markdown]
# ### K Mean Clustering 구현해보기

# %%
# default
x = np.array([1,6,7,3,6,2,2])
y = np.array([1,6,7,2,8,1,3])

c1 = np.array([11.0,3.0])
c2 = np.array([7.0,9.0]) # k클러스터 개수

# %%
def k_mean_clustering(x,y, c1,c2, iteration):
    # K Mean Clustering
    for i in range(iteration):
        
        # distance
        c1_l2 = np.sqrt(((x-c1[0])**2 + (y-c1[1])**2))
        c2_l2 = np.sqrt(((x-c2[0])**2 + (y-c2[1])**2))
        r1_x = []
        r1_y = []
        r2_x = []
        r2_y = []
        for i in range(len(c1_l2)):
            if(c1_l2[i] > c2_l2[i]):
                r2_x.append(x[i])
                r2_y.append(y[i])
            if(c1_l2[i] < c2_l2[i]):
                r1_x.append(x[i])
                r1_y.append(y[i])
        previous_c1 = c1.copy()
        previous_c2 = c2.copy()

        # mean
        c1[0] = np.mean(r1_x)
        c1[1] = np.mean(r1_y)

        c2[0] = np.mean(r2_x)
        c2[1] = np.mean(r2_y)


        if((np.sum(previous_c1 == c1)==2) and (np.sum(previous_c2 == c2)==2)):
            break
    return c1, c2

# %%
# visualization
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title("before")
plt.plot(x,y,'o')
plt.plot(c1[0],c1[1],'x',)
plt.plot(c2[0],c2[1],'xr')


# K Mean Clustering
c1, c2 = k_mean_clustering(x,y,c1,c2,1)
    
# visualization
plt.subplot(1,2,2)
plt.title("after")
plt.plot(x,y,'o')
plt.plot(c1[0],c1[1],'x',)
plt.plot(c2[0],c2[1],'xr')
plt.show()

# %%
w = np.concatenate((np.random.uniform(0,10,10),np.random.uniform(10,20,10)))
h = np.concatenate((np.random.uniform(0,10,10),np.random.uniform(10,20,10)))

a1 = np.random.uniform(0,20,30)
a2 = np.random.uniform(0,20,30)

# %%
# visualization
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title("before")
plt.plot(w,h,'o')
plt.plot(a1[0],a1[1],'x',)
plt.plot(a2[0],a2[1],'xr')


# K Mean Clustering
a1, a2 = k_mean_clustering(w,h,a1,a2,30)
    
# visualization
plt.subplot(1,2,2)
plt.title("after")
plt.plot(w,h,'o')
plt.plot(a1[0],a1[1],'x',)
plt.plot(a2[0],a2[1],'xr')
plt.show()

# %%
import os
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
annotation_path = "/jupyterNotebook/datasets/face_with_mask_detection/Medical_mask/Medical_mask/Medical_Mask/annotations/"

# %%
image_path = "/jupyterNotebook/datasets/face_with_mask_detection/Medical_mask/Medical_mask/Medical_Mask/images/"

# %%
annotation_list = os.listdir(annotation_path)

# %%
len(annotation_list)
# Out:
# 4326

# %%
try:
    annotation_list.remove('.DS_Store')
except Exception as e:
    print("Not ('.DS_Store'")
# Out:
# Not ('.DS_Store'

# %%
annotation_list.sort()

# %%
json_datas = []
image_datas = []
max_num = 0
for i in range(len(annotation_list)):
    with open(os.path.join(annotation_path,annotation_list[i]),"r") as json_file:
        json_data = json.load(json_file)
        
    length = len(json_data.get("Annotations"))
    count = 0
    for j in range(length):
        name = json_data['Annotations'][j]['classname']
        if(name[:4]=="face"):
            count +=1
        
        if(count > 3):
            break
    if(count <= 3):
        json_datas.append(json_data)
        
        test_image = cv2.imread(image_path+json_data['FileName'])
        test_image = cv2.cvtColor(test_image,cv2.COLOR_BGR2RGB)
        
        image_datas.append(test_image)
    if(i%200==0):
        print(".",end=' ')
# Out:
# . . . . . . . . . . . . . . . . . . . . . .

# %%
IMAGE_SIZE = 224

# %%
## anchor 
anchors_w = []
anchors_h = []
for i in range(len(json_datas)):
    annotaions = json_datas[i]['Annotations']
    image_size = image_datas[i].shape
    for j in range(len(annotaions)):
        boudingBox = annotaions[0]["BoundingBox"]
        width = ((boudingBox[2] - boudingBox[0])/image_size[1])*IMAGE_SIZE
        anchors_w.append(width)
        height = ((boudingBox[3] - boudingBox[1])/image_size[0])*IMAGE_SIZE
        anchors_h.append(height)

# %%
def processing(images, json_data_list, re_size=416):
    preprocessing_xData = []
    preprocessing_yData = []
    for i in range(len(json_data_list)):
        
        # initial_value
        test_image = images[i]
        image_size = test_image.shape
        
        # resizing image
        while True:
            shape = test_image.shape[:2]
            if(int(shape[0]/2)<=re_size or int(shape[1]/2)<=re_size):
                test_image = cv2.resize(test_image,(re_size,re_size))
                break
            test_image = cv2.resize(test_image,(int(shape[0]/2),int(shape[1]/2)))
        preprocessing_xData.append(test_image)
            
        
        # bounding label
        annotaions = json_data_list[i]['Annotations']

        
        indexs = []
        element = np.zeros((1,13,13,6))
        for j in range(len(annotaions)):
            name = annotaions[j]['classname']
            if name[:4]=="face":
                boudingBox = annotaions[j]["BoundingBox"]
                xmin = boudingBox[0]
                ymin = boudingBox[1]
                xmax = boudingBox[2]
                ymax = boudingBox[3]
                
                delta_x = (((xmax+xmin)/2)/image_size[1])*re_size
                delta_y = (((ymax+ymin)/2)/image_size[0])*re_size

                width = ((xmax - xmin)/image_size[1])*re_size
                height = ((ymax - ymin)/image_size[0])*re_size
                
                classes = 0     
                if (name[:14]=="face_with_mask"):
                    classes = 1 # with mask
                else:
                    classes = 0 # with no mask

                row = int(delta_y/(re_size/13))
                column = int(delta_x/(re_size/13))
                index = row*13 + (column+1) -1

                if len(indexs)>0:
                    check = 0
                    for v in range(len(indexs)):
                        if(index == indexs[v]):
                            check = 1
                            
                    if(check==0):
                        element[0,row, column, 0] = 1        # confidence
                        element[0,row, column, 1] = delta_x  # bx(center)
                        element[0,row, column, 2] = delta_y  # by(center)
                        element[0,row, column, 3] = width    # bw
                        element[0,row, column, 4] = height   # bh
                        element[0,row, column, 5] = classes  # class
                        
                        indexs.append(index)

                else:
                    element[0,row, column, 0] = 1        # confidence
                    element[0,row, column, 1] = delta_x  # bx(center)
                    element[0,row, column, 2] = delta_y  # by(center)
                    element[0,row, column, 3] = width    # bw
                    element[0,row, column, 4] = height   # bh
                    element[0,row, column, 5] = classes  # class

                    indexs.append(index)
                
        
        preprocessing_yData.append(element)
        
        if(i%200 ==0):
            print(".",end=" ")
        
        
    preprocessing_xData = np.array(preprocessing_xData)
    preprocessing_yData = np.concatenate(preprocessing_yData)
    
    
    return (preprocessing_xData, preprocessing_yData)

# %%
preprocessing_xData, preprocessing_yData = processing(image_datas,json_datas,re_size=IMAGE_SIZE)
# Out:
# . . . . . . . . . . . . . . . . . . . .

# %%
np.save('/Users/changmin.kim/Downloads/preprocessing_xData.npy',preprocessing_xData,allow_pickle=True)

# %%
np.save('/Users/changmin.kim/Downloads/preprocessing_yData.npy',preprocessing_yData,allow_pickle=True)

# %%
from matplotlib.patches import Rectangle

# %%
# visualization
def visualization():
    num = np.random.randint(len(preprocessing_yData))
    plt.imshow(preprocessing_xData[num])
    position = preprocessing_yData[num][:12]
    for i in range(3):
        rect = Rectangle(( (position[4*i+0]-position[4*i+2]/2), (position[4*i+1]-position[4*i+3]/2) ), position[4*i+2],position[4*i+3],fill=False,color="red")
        plt.axes().add_patch(rect)
    plt.show()

# %%
# visualization
def visualization():
    fig, axs = plt.subplots(1, 6, figsize=(15, 3), sharey=True)
    num = np.random.randint(0,len(preprocessing_yData),6)

    for j in range(6):
        number = num[j]
        confidence = preprocessing_yData[number][:,:,0]

        position = np.where(confidence==1)
        bounding_box = preprocessing_yData[number][:,:,1:5]

        axs[j].imshow(preprocessing_xData[number])
        if(len(position[0])==1):
            column = position[1]
            row = position[0]

            bx = bounding_box[row,column,0]
            by = bounding_box[row,column,1]
            bw = bounding_box[row,column,2]
            bh = bounding_box[row,column,3]


            bxmin = bx - bw/2
            bymin = by - bh/2

            rect = Rectangle((bxmin, bymin), bw,bh,fill=False,color="red")
            axs[j].add_patch(rect)

        else:
            for v in range(len(position[0])):

                row = position[0][v]
                column = position[1][v]

                bx = bounding_box[row,column,0]
                by = bounding_box[row,column,1]
                bw = bounding_box[row,column,2]
                bh = bounding_box[row,column,3]


                bxmin = bx - bw/2
                bymin = by - bh/2


                rect = Rectangle((bxmin, bymin), bw,bh,fill=False,color="red",)
                axs[j].add_patch(rect)

    fig.suptitle('Bounding And Confidence')
    plt.show()
    fig, axs = plt.subplots(1, 6, figsize=(15, 5), sharey=True)
    for i in range(6):
        number = num[i]
        confidence = preprocessing_yData[number][:,:,0]
        axs[i].imshow(confidence)
    plt.show()

# %%
visualization()

# %%
num = 1000

# %%
plt.imshow(preprocessing_xData[num])
plt.show()

# %%
fig = plt.figure()

for i in range(4):
    ax = fig.add_subplot(1,4,1+i)
    p = ax.imshow(preprocessing_yData[num,:,:,i])
    plt.colorbar(p)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
anchors_w = preprocessing_yData[:,2:4][:,0]
anchors_h = preprocessing_yData[:,2:4][:,1]

# %%
anchors_w = []
anchors_h = []
index = np.where(preprocessing_yData[:,:,:,0]!=0)
for i in range(len(index[0])):
    w = preprocessing_yData[index[0][i], index[1][i], index[2][i],3]
    h = preprocessing_yData[index[0][i], index[1][i], index[2][i],4]
    
    anchors_w.append(w)
    anchors_h.append(h)

# %%
k_mean_model = KMeans(n_clusters=4).fit(np.transpose(np.array([anchors_w,anchors_h]),axes=[1,0]))

# %%
k_means = k_mean_model.cluster_centers_

# %%
k_means
# Out:
# array([[276.46709904, 351.85270211],
#        [ 52.87250472,  81.10334548],
#        [106.59493947, 170.54810571],
#        [181.4208717 , 266.35600361]])

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

plt.figure(figsize=(5,5))
plt.xlabel('width')
plt.ylabel('height')
for i in range(len(k_means)):
    plt.axes().add_patch(
        patches.Rectangle(
            (200-(k_means[i][0]/2),200-(k_means[i][1]/2)),   # (x,y)
            k_means[i][0],          # width
            k_means[i][1],          # height
            facecolor="purple",
            alpha=0.1
        )
    )
    plt.xlim([0,400])
    plt.ylim([0,400])
# Out:
# /Users/changmin.kim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.plot(anchors_w,anchors_h,'.')
plt.xlabel('width')
plt.ylabel('height')
plt.plot(k_means[0][0],k_means[0][1],'Xr',)
plt.plot(k_means[1][0],k_means[1][1],'Xr',)
plt.plot(k_means[2][0],k_means[2][1],'Xr',)
plt.plot(k_means[3][0],k_means[3][1],'Xr',)

plt.show()

# %% [markdown]
# ## LOSS
# ___
# - Grid cell의 여러 bounding box들 중, ground-truth box와 의. iou와의 iou가 가장 높은 bounding box를 predictor로 설정한다.
# - iou가 적어도 0.6 이상이여야 bounding box와 ground-truth와 관련 있다고 본다.
# ![](https://curt-park.github.io/images/yolo/lossFunction.JPG)
# - (1): Object가 존재하는 grid cell i의 predictor bounding box j에 대해, x와 y의 loss를 계산.
# - (2): Object가 존재하는 grid cell i의 predictor bounding box j에 대해, w와 h의 loss를 계산.
#     - 큰 box에 대해서는 small deviation을 반영하기 위해 제곱근을 취한 후, sum-squared error를 한다.
#     - 같은 error라도 larger box의 경우 상대적으로 IOU에 영향을 적게 준다.
#     - 제곱근을 취하지 않으면  상대적으로 loss는 큰 박스 위주로 학습하기 때문에 작은 박스는 신경을 안쓰게 될 수 있다.
#         - ex) sqrt(300) -> 17 , sqrt(200) -> 14
# - (3): Object가 존재하는 grid cell i의 predictor bounding box j에 대해, confidence score의 loss를 계산. (Ci = 1)
# - (4): Object가 존재하지 않는 grid cell i의 bounding box j에 대해, confidence score의 loss를 계산. (Ci = 0)
# - (5): Object가 존재하는 grid cell i에 대해, conditional class probability의 loss 계산
# ___
#
# ___
# s: size(row 또는 column의 크기)
# i: cell의 인덱스
# j: bouding box predictor의 index
# ![](https://curt-park.github.io/images/yolo/notation.JPG)
# > (1): Object가 존재하는 grid cell i의 predictor bounding box j (iou >= 0.6) <br>
# > (2): Object가 존재하지 않는 grid cell i의 bounding box j (iou < 0.6) <br>
# > (3): Object가 존재하는 grid cell i <br>
#
# λcoord:
# - coordinates(x,y,w,h)에 대한 loss와 다른 loss들과의 균형을 위한 balancing parameter.
# - 5
#
# λnoobj:
# - obj가 있는 box와 없는 box간에 균형을 위한 balancing parameter.
# - 일반적으로 image내에는 obj가 있는 cell보다는 obj가 없는 cell이 훨씬 많으므로 모델은 오직 no obj에 대해서만 학습 하는 경향이 생긴다.
# - 0.5
# ___

# %% [markdown]
# ### Detectors with no ground-truth (negative examples)
# $${noobject_loss[i, j, b] = noobjectscale * (0 - sigmoid(predconf[i, j, b]))^2}$$

# %% [markdown]
# find their object or when they misclassify the object. There are three separate loss terms that deal with this

# %% [markdown]
# ### Detectors with a ground-truth (positive examples)
#
# #### Confidence score
# object_loss[i, j, b] = object_scale *
#          (IOU(truth_coords, pred_coords) - sigmoid(pred_conf[i, j, b]))**2

# %% [markdown]
# The predicted confidence score pred_conf[i, j, b] is supposed to represent the IOU between the predicted bounding box and the ground-truth box

# %% [markdown]
# Actually, YOLO has another trick up its sleeve. If the best IOU between a detector’s prediction and any of the ground-truth boxes in the image is greater than, say 60%, then no_object_loss[i, j, b] is set to 0.

# %% [markdown]
# 예측 신뢰 점수 pred_conf[i, j, b]는 예측 경계 상자와 실측 값 상자 사이의 IOU를 나타냅니다. 이상적으로는 완벽한 일치를 위해 1 또는 100 %입니다. 그러나 예상 점수를이 이상적인 숫자와 비교하는 대신 YOLO는 두 상자 간의 실제 IOU를 살펴 봅니다 .
#
# 이는 의미가 있습니다. IOU가 작 으면 신뢰도는 작아야하고 IOU가 크면 신뢰도도 커야합니다.
#
# 예측 신뢰도가 항상 0이되기를 원하는 객체없는 손실과는 달리, 여기서는 모델이 항상 100 % 신뢰도를 예측하는 것을 원하지 않습니다. 대신 모델은 경계 상자 좌표가 얼마나 좋은지 추정하는 방법을 배워야합니다. 그리고 그것이 바로 IOU가 여러분에게 말하는 것입니다.

# %% [markdown]
# #### Class probabilities

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras.backend as K
import numpy as np

# %%
IMAGE_SIZE = 416

# %%
inception = InceptionV3(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False)

# %%
# Maximize the activation of these layers
name = 'mixed7'

# %%
out_layer = inception.get_layer(name).output

# %%
bx = np.zeros((1,13,13,1))

by = np.zeros((1,13,13,1))


for i in range(13):
    bx[0,:,i,0] = i
    
for i in range(13):
    by[0,i,:,0] = i

# %%
out_layer = layers.Conv2D(768,(3,3),kernel_initializer="he_normal")(out_layer)
out_layer = layers.BatchNormalization()(out_layer)
out_layer = layers.Activation('relu')(out_layer)

out_layer = layers.Conv2D(1024,(3,3),kernel_initializer="he_normal")(out_layer)
out_layer = layers.BatchNormalization()(out_layer)
out_layer = layers.Activation('relu')(out_layer)

out_layer = layers.Conv2D(512,(5,5),kernel_initializer="he_normal")(out_layer)
out_layer = layers.BatchNormalization()(out_layer)
out_layer = layers.Activation('relu')(out_layer)

out_layer = layers.Conv2D(256,(3,3),kernel_initializer="he_normal")(out_layer)
out_layer = layers.BatchNormalization()(out_layer)
out_layer = layers.Activation('relu')(out_layer)

out_layer = layers.Conv2D(24,(2,2))(out_layer)



concatenate_list = []
for i in range(4):
    # One of Detectors
    predicted_confidence = out_layer[:,:,:,i*6:i*6+1]
    
    delta_x = out_layer[:,:,:,i*6+1:i*6+2]
    delta_y = out_layer[:,:,:,i*6+2:i*6+3]
    
    delta_w = out_layer[:,:,:,i*6+3:i*6+4]
    delta_h = out_layer[:,:,:,i*6+4:i*6+5]
    
    predicted_classes = out_layer[:,:,:,i*6+5:i*6+6]
    
    
    # Activation
    out_layer_c = K.sigmoid(predicted_confidence)  # confidence
    
    out_layer_bx = (K.sigmoid(delta_x) + bx)*32    # boudning_x
    out_layer_by = (K.sigmoid(delta_y) + by)*32    # bouding_y
            
    out_layer_bw = k_means[i][0]*K.exp(delta_w)    # boudnign_width
    out_layer_bh = k_means[i][1]*K.exp(delta_h)    # boudning_height
    
    out_layer_class = K.sigmoid(predicted_classes) # classes
    
    concatenate_list.append(out_layer_c)
    concatenate_list.append(out_layer_bx)
    concatenate_list.append(out_layer_by)
    concatenate_list.append(out_layer_bw)
    concatenate_list.append(out_layer_bh)
    concatenate_list.append(out_layer_class)
    
# concatenate
out_layer = layers.Concatenate(axis=3)(concatenate_list)

# %%
out_layer
# Out:
# <tf.Tensor 'concatenate_4/Identity:0' shape=(None, 13, 13, 24) dtype=float32>

# %%
from tensorflow.keras import Input, Model

# %%
object_model = tf.keras.Model(inputs=inception.input, outputs=out_layer)

# %%
object_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 207, 207, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 207, 207, 32) 96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 207, 207, 32) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 205, 205, 32) 9216        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 205, 205, 32) 96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 205, 205, 32) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 205, 205, 64) 18432       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 205, 205, 64) 192         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 205, 205, 64) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 102, 102, 64) 0           activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 102, 102, 80) 5120        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 102, 102, 80) 240         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 102, 102, 80) 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 100, 100, 192 138240      activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 100, 100, 192 576         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 100, 100, 192 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 49, 49, 192)  0           activation_98[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 49, 49, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 49, 49, 64)   192         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 49, 49, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 49, 49, 48)   9216        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 49, 49, 96)   55296       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 49, 49, 48)   144         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 49, 49, 96)   288         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 49, 49, 48)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 49, 49, 96)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 49, 49, 192)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 49, 49, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 49, 49, 64)   76800       activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 49, 49, 96)   82944       activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 49, 49, 32)   6144        average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 49, 49, 64)   192         conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 49, 49, 64)   192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 49, 49, 96)   288         conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 49, 49, 32)   96          conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 49, 49, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 49, 49, 64)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 49, 49, 96)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 49, 49, 32)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 49, 49, 256)  0           activation_99[0][0]
#                                                                  activation_101[0][0]
#                                                                  activation_104[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 49, 49, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 49, 49, 64)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 49, 49, 64)   0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 49, 49, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 49, 49, 96)   55296       activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 49, 49, 48)   144         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 49, 49, 96)   288         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 49, 49, 48)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 49, 49, 96)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 49, 49, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 49, 49, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 49, 49, 64)   76800       activation_107[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 49, 49, 96)   82944       activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 49, 49, 64)   16384       average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 49, 49, 64)   192         conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 49, 49, 64)   192         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 49, 49, 96)   288         conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 49, 49, 64)   192         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 49, 49, 64)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 49, 49, 64)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 49, 49, 96)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 49, 49, 64)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 49, 49, 288)  0           activation_106[0][0]
#                                                                  activation_108[0][0]
#                                                                  activation_111[0][0]
#                                                                  activation_112[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 49, 49, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 49, 49, 64)   192         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 49, 49, 64)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 49, 49, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 49, 49, 96)   55296       activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 49, 49, 48)   144         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 49, 49, 96)   288         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 49, 49, 48)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 49, 49, 96)   0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 49, 49, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 49, 49, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 49, 49, 64)   76800       activation_114[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 49, 49, 96)   82944       activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 49, 49, 64)   18432       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 49, 49, 64)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 49, 49, 64)   192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 49, 49, 96)   288         conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 49, 49, 64)   192         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 49, 49, 64)   0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 49, 49, 64)   0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 49, 49, 96)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 49, 49, 64)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 49, 49, 288)  0           activation_113[0][0]
#                                                                  activation_115[0][0]
#                                                                  activation_118[0][0]
#                                                                  activation_119[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 49, 49, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 49, 49, 64)   192         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 49, 49, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 49, 49, 96)   55296       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 49, 49, 96)   288         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 49, 49, 96)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 24, 24, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 24, 24, 96)   82944       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 24, 24, 384)  1152        conv2d_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 24, 24, 96)   288         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 24, 24, 384)  0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 24, 24, 96)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 24, 24, 768)  0           activation_120[0][0]
#                                                                  activation_123[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 24, 24, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 24, 24, 128)  384         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 24, 24, 128)  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 24, 24, 128)  114688      activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 24, 24, 128)  384         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 24, 24, 128)  0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 24, 24, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 24, 24, 128)  114688      activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 24, 24, 128)  384         conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 24, 24, 128)  384         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 24, 24, 128)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 24, 24, 128)  0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 24, 24, 128)  114688      activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 24, 24, 128)  114688      activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 24, 24, 128)  384         conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 24, 24, 128)  384         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 24, 24, 128)  0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 24, 24, 128)  0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 24, 24, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 24, 24, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 24, 24, 192)  172032      activation_126[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 24, 24, 192)  172032      activation_131[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 24, 24, 192)  147456      average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 24, 24, 192)  576         conv2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 24, 24, 192)  576         conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 24, 24, 192)  576         conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 24, 24, 192)  576         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 24, 24, 192)  0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 24, 24, 192)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 24, 24, 192)  0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 24, 24, 192)  0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 24, 24, 768)  0           activation_124[0][0]
#                                                                  activation_127[0][0]
#                                                                  activation_132[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 24, 24, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 24, 24, 160)  480         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 24, 24, 160)  0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 24, 24, 160)  179200      activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 24, 24, 160)  480         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 24, 24, 160)  0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 24, 24, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 24, 24, 160)  179200      activation_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 24, 24, 160)  480         conv2d_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 24, 24, 160)  480         conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 24, 24, 160)  0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 24, 24, 160)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 24, 24, 160)  179200      activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 24, 24, 160)  179200      activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 24, 24, 160)  480         conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 24, 24, 160)  480         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 24, 24, 160)  0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 24, 24, 160)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 24, 24, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 24, 24, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 24, 24, 192)  215040      activation_136[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 24, 24, 192)  215040      activation_141[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 24, 24, 192)  147456      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 24, 24, 192)  576         conv2d_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 24, 24, 192)  576         conv2d_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 24, 24, 192)  576         conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 24, 24, 192)  576         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 24, 24, 192)  0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 24, 24, 192)  0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 24, 24, 192)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 24, 24, 192)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 24, 24, 768)  0           activation_134[0][0]
#                                                                  activation_137[0][0]
#                                                                  activation_142[0][0]
#                                                                  activation_143[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 24, 24, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 24, 24, 160)  480         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 24, 24, 160)  0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 24, 24, 160)  179200      activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 24, 24, 160)  480         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 24, 24, 160)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 24, 24, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 24, 24, 160)  179200      activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 24, 24, 160)  480         conv2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 24, 24, 160)  480         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 24, 24, 160)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 24, 24, 160)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 24, 24, 160)  179200      activation_145[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 24, 24, 160)  179200      activation_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 24, 24, 160)  480         conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 24, 24, 160)  480         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 24, 24, 160)  0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 24, 24, 160)  0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 24, 24, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 24, 24, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 24, 24, 192)  215040      activation_146[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 24, 24, 192)  215040      activation_151[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 24, 24, 192)  147456      average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 24, 24, 192)  576         conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 24, 24, 192)  576         conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 24, 24, 192)  576         conv2d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 24, 24, 192)  576         conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 24, 24, 192)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 24, 24, 192)  0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 24, 24, 192)  0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 24, 24, 192)  0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 24, 24, 768)  0           activation_144[0][0]
#                                                                  activation_147[0][0]
#                                                                  activation_152[0][0]
#                                                                  activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 24, 24, 192)  576         conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 24, 24, 192)  0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 24, 24, 192)  258048      activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 24, 24, 192)  576         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 24, 24, 192)  0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 24, 24, 192)  258048      activation_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 24, 24, 192)  576         conv2d_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 24, 24, 192)  576         conv2d_160[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 24, 24, 192)  0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 24, 24, 192)  0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 24, 24, 192)  258048      activation_155[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 24, 24, 192)  258048      activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 24, 24, 192)  576         conv2d_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 24, 24, 192)  576         conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 24, 24, 192)  0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 24, 24, 192)  0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 24, 24, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 24, 24, 192)  258048      activation_156[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 24, 24, 192)  258048      activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 24, 24, 192)  147456      average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 24, 24, 192)  576         conv2d_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 24, 24, 192)  576         conv2d_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 24, 24, 192)  576         conv2d_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 24, 24, 192)  576         conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 24, 24, 192)  0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 24, 24, 192)  0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 24, 24, 192)  0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 24, 24, 192)  0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 24, 24, 768)  0           activation_154[0][0]
#                                                                  activation_157[0][0]
#                                                                  activation_162[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# ...
# tf_op_layer_strided_slice_14 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_19 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_20 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_1 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_2 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_3 (Te [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_4 (Te [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_5 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_6 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_9 (Te [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_10 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_9 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_13[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_10 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_14[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_15 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_16 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_13 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_19[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_14 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_20[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_21 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_22 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_1 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_5 (Te [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_2 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_3 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_2 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_3 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_10[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_11 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_12 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_4 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_15[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Exp_5 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_16[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_17 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_18 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_6 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_7 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Sigmoid_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_6 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_21[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Exp_7 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_22[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_23 (T [(None, 13, 13, 1)]  0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid (TensorFlow [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul (TensorFlowOpLa [(None, 13, 13, 1)]  0           tf_op_layer_add[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_1 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_2 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_3 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_3 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_4 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_4 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_5 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_add_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_6 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Exp_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_7 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_Exp_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_7 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_11[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_8 (TensorFl [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_12[0][0
# __________________________________________________________________________________________________
# tf_op_layer_mul_8 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_9 (TensorFlowOp [(None, 13, 13, 1)]  0           tf_op_layer_add_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_10 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_Exp_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_11 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_Exp_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_11 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_17[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_12 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_18[0][0
# __________________________________________________________________________________________________
# tf_op_layer_mul_12 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_13 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_add_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_14 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_Exp_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_15 (TensorFlowO [(None, 13, 13, 1)]  0           tf_op_layer_Exp_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_15 (TensorF [(None, 13, 13, 1)]  0           tf_op_layer_strided_slice_23[0][0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 13, 13, 24)   0           tf_op_layer_Sigmoid[0][0]
#                                                                  tf_op_layer_mul[0][0]
#                                                                  tf_op_layer_mul_1[0][0]
#                                                                  tf_op_layer_mul_2[0][0]
#                                                                  tf_op_layer_mul_3[0][0]
#                                                                  tf_op_layer_Sigmoid_3[0][0]
#                                                                  tf_op_layer_Sigmoid_4[0][0]
#                                                                  tf_op_layer_mul_4[0][0]
#                                                                  tf_op_layer_mul_5[0][0]
#                                                                  tf_op_layer_mul_6[0][0]
#                                                                  tf_op_layer_mul_7[0][0]
#                                                                  tf_op_layer_Sigmoid_7[0][0]
#                                                                  tf_op_layer_Sigmoid_8[0][0]
#                                                                  tf_op_layer_mul_8[0][0]
#                                                                  tf_op_layer_mul_9[0][0]
#                                                                  tf_op_layer_mul_10[0][0]
#                                                                  tf_op_layer_mul_11[0][0]
#                                                                  tf_op_layer_Sigmoid_11[0][0]
#                                                                  tf_op_layer_Sigmoid_12[0][0]
#                                                                  tf_op_layer_mul_12[0][0]
#                                                                  tf_op_layer_mul_13[0][0]
#                                                                  tf_op_layer_mul_14[0][0]
#                                                                  tf_op_layer_mul_15[0][0]
#                                                                  tf_op_layer_Sigmoid_15[0][0]
# ==================================================================================================
# Total params: 35,685,816
# Trainable params: 35,661,880
# Non-trainable params: 23,936
# __________________________________________________________________________________________________

# %%
num = np.random.randint(0,len(preprocessing_yData))
print(num)
# Out:
# 3822

# %%
name = {0:'with_no_mask',1:'with_mask'}

# %%
plt.imshow(preprocessing_xData[num])
plt.title(name[np.sum(preprocessing_yData[num,:,:,5])!=0])
plt.show()

# %%
test_image = preprocessing_xData[num:num+1].copy()

test_label = preprocessing_yData[num:num+1].copy()

# %%
test_image = test_image.astype('float32')
test_image = (2*test_image - 255)/255

# %%
result = object_model(test_image)

# %%
result.shape
# Out:
# TensorShape([1, 13, 13, 24])

# %%
name = ['confidence','bounding_x','bounding_y','bounding_w','bouding_h','class']

# %%
fig = plt.figure()           # Define "figure" instance
fig.set_size_inches(16,3)    # Physical page size in inches, (lx,ly)
suptit="Bounding Box Of One Object Detector"
fig.suptitle(suptit,fontsize=18,y=0.99)   # Title for the page
fig.subplots_adjust(left=0.02,right=1,bottom=0.1,top=0.7,wspace=0.3,hspace=0.3)

for i in range(6):
    ax = fig.add_subplot(1,6,i+1)
    pic1 = ax.imshow(result[:,:,:,i].numpy()[0])
    plt.title(name[i])
    plt.colorbar(pic1)
plt.show()

# %% [markdown]
# ### LOSS

# %%
# IOU
def get_iou(y_truth, y_pred):
    """
    y_truth : shape=(:,13,13,6)
    y_pred  : shape=(:,13,13,6*4)
    """
    
    iou = []
    for i in range(4):
        # intersect
        intersect = (  K.minimum(y_truth,y_pred[:,:,:,i*6:6*i+6])[:,:,:,3:4]  *  K.minimum(y_truth,y_pred[:,:,:,i*6:6*i+6])[:,:,:,4:5]  )

        # union
        union = ((y_pred[:,:,:,i*6:6*i+6][:,:,:,3:4])*(y_pred[:,:,:,i*6:6*i+6][:,:,:,4:5]))  +  ((y_truth[:,:,:,3:4]) * (y_truth[:,:,:,4:5]))  -  (intersect)

        # iou
        iou.append(intersect/union)
        
    iou = K.concatenate(iou)
    
    
    return iou

# %%
y_true = test_label
y_pred = result

# %%
test_iou = get_iou(y_true,y_pred)

# %%
fig = plt.figure()           # Define "figure" instance
fig.set_size_inches(16,3)    # Physical page size in inches, (lx,ly)
suptit="Bounding Box Of One Object Detector"
fig.suptitle(suptit,fontsize=18,y=0.99)   # Title for the page
fig.subplots_adjust(left=0.02,right=1,bottom=0.1,top=0.7,wspace=0.3,hspace=0.3)

name = ['detector1', 'detector2', 'detector3', 'detector4']

all_value = 0

for i in range(4):
    ax = fig.add_subplot(1,5,i+1)
    pic1 = ax.imshow(test_iou[0,:,:,i])
    plt.title(name[i])
    plt.colorbar(pic1)
    all_value += test_iou[0,:,:,i]
    
ax = fig.add_subplot(1,5,5)
pic1 = ax.imshow(all_value,vmin=0,vmax=1)
plt.title("all_detector")
plt.colorbar(pic1)
plt.show()

# %%
def custom_loss(y_true, y_pred):
    # y_true: shape=(:,13,13,6)
    # y_pred: shape=(:,13,13,6*4)
    
    lambda_coord = 5
    lambda_noobj = 0.05
    
    b = y_true.shape[0]
    print(b)
    
    
    iou = get_iou(y_true,y_pred)    # iou_one_hot    (:,13,13,4)
    
    objness_label = y_true[:,:,:,0] # confidence     (:,13,13,1)
    
    x_label = y_true[:,:,:,1]       # ground_truth_x (:,13,13,1)
    y_label = y_true[:,:,:,2]       # ground_truth_y (:,13,13,1)
    width_label = y_true[:,:,:,3]   # ground_truth_w (:,13,13,1)
    height_label = y_true[:,:,:,4]  # ground_truth_h (:,13,13,1)
    
    class_label = y_true[:,:,:,5]   # class          (:,13,13,1)
    
    
    total_loss = 0
    for i in range(4):
        # Bounding Box (:,13,13,1)
        obj_coord_loss = objness_label * (K.square(K.sqrt(x_label) - K.sqrt(y_pred[:,:,:,i*6+1])) + K.square(K.sqrt(y_label) - K.sqrt(y_pred[:,:,:,i*6+2]))) 
        obj_size_loss  = objness_label * K.sqrt(K.square(K.sqrt(width_label) - K.sqrt(y_pred[:,:,:,i*6+3])) + K.square(K.sqrt(height_label) - K.sqrt(y_pred[:,:,:,i*6+4]))) 
        
        # confidencev (:,13,13,1)
        objness_loss   = objness_label * K.square((iou[:,:,:,i] * objness_label)-y_pred[:,:,:,i*6+0])
        
        noobjness_loss = (1-objness_label) * K.square(objness_label-y_pred[:,:,:,i*6+0]) 
        
        # class (:,13,13,1)
        obj_class_loss = objness_label * K.square(class_label-y_pred[:,:,:,i*6+5])
        
        # sum
        obj_coord_loss = lambda_coord * K.sum(obj_coord_loss)
        print(obj_coord_loss)
        obj_size_loss  = lambda_coord * K.sum(obj_size_loss)
        print(obj_size_loss)
        objness_loss   = K.sum(objness_loss)
        print(objness_loss)
        noobjness_loss = lambda_noobj * K.sum(noobjness_loss)
        print(noobjness_loss)
        obj_class_loss = K.sum(obj_class_loss)
        print(obj_class_loss)
        total_loss += (obj_coord_loss + obj_size_loss + objness_loss + noobjness_loss + obj_class_loss)
        print("total:",total_loss)
        print("")
        
    total_loss /= b 
    
    return total_loss

# %%
y_true_k = K.variable(y_true)
y_pred_k = K.variable(y_pred)

# %%
custom_loss(y_true_k,y_pred_k)
# Out:
# 1
# tf.Tensor(8.806503, shape=(), dtype=float32)
# tf.Tensor(110.0957, shape=(), dtype=float32)
# tf.Tensor(0.5789608, shape=(), dtype=float32)
# tf.Tensor(2.8644009, shape=(), dtype=float32)
# tf.Tensor(0.7279128, shape=(), dtype=float32)
# total: tf.Tensor(123.07349, shape=(), dtype=float32)
#
# tf.Tensor(16.785564, shape=(), dtype=float32)
# tf.Tensor(14.240346, shape=(), dtype=float32)
# tf.Tensor(0.06021296, shape=(), dtype=float32)
# tf.Tensor(2.5052023, shape=(), dtype=float32)
# tf.Tensor(0.34302592, shape=(), dtype=float32)
# total: tf.Tensor(157.00784, shape=(), dtype=float32)
#
# tf.Tensor(6.395743, shape=(), dtype=float32)
# tf.Tensor(38.168648, shape=(), dtype=float32)
# tf.Tensor(0.07196849, shape=(), dtype=float32)
# tf.Tensor(1.5396131, shape=(), dtype=float32)
# tf.Tensor(0.5994423, shape=(), dtype=float32)
# total: tf.Tensor(203.78326, shape=(), dtype=float32)
#
# tf.Tensor(8.9619255, shape=(), dtype=float32)
# tf.Tensor(157.41718, shape=(), dtype=float32)
# tf.Tensor(0.28770673, shape=(), dtype=float32)
# tf.Tensor(2.0228388, shape=(), dtype=float32)
# tf.Tensor(0.63468623, shape=(), dtype=float32)
# total: tf.Tensor(373.1076, shape=(), dtype=float32)
# <tf.Tensor: shape=(), dtype=float32, numpy=373.1076>

# %%
xTrain = (2*preprocessing_xData.astype('float32') - 255)/255

# %%
np.save('/Users/changmin.kim/Downloads/xTrain.npy',xTrain,allow_pickle=True)

# %%
# np.save('/Users/changmin.kim/Downloads/yTrain.npy',preprocessing_yData,allow_pickle=True)

# %%
# Out:
# array([-1.        , -0.99215686, -0.9843137 , -0.9764706 , -0.96862745,
#        -0.9607843 , -0.9529412 , -0.94509804, -0.9372549 , -0.92941177,
#        -0.92156863, -0.9137255 , -0.90588236, -0.8980392 , -0.8901961 ,
#        -0.88235295, -0.8745098 , -0.8666667 , -0.85882354, -0.8509804 ,
#        -0.84313726, -0.8352941 , -0.827451  , -0.81960785, -0.8117647 ,
#        -0.8039216 , -0.79607844, -0.7882353 , -0.78039217, -0.77254903,
#        -0.7647059 , -0.75686276, -0.7490196 , -0.7411765 , -0.73333335,
#        -0.7254902 , -0.7176471 , -0.70980394, -0.7019608 , -0.69411767,
#        -0.6862745 , -0.6784314 , -0.67058825, -0.6627451 , -0.654902  ,
#        -0.64705884, -0.6392157 , -0.6313726 , -0.62352943, -0.6156863 ,
#        -0.60784316, -0.6       , -0.5921569 , -0.58431375, -0.5764706 ,
#        -0.5686275 , -0.56078434, -0.5529412 , -0.54509807, -0.5372549 ,
#        -0.5294118 , -0.52156866, -0.5137255 , -0.5058824 , -0.49803922,
#        -0.49019608, -0.48235294, -0.4745098 , -0.46666667, -0.45882353,
#        -0.4509804 , -0.44313726, -0.43529412, -0.42745098, -0.41960785,
#        -0.4117647 , -0.40392157, -0.39607844, -0.3882353 , -0.38039216,
#        -0.37254903, -0.3647059 , -0.35686275, -0.34901962, -0.34117648,
#        -0.33333334, -0.3254902 , -0.31764707, -0.30980393, -0.3019608 ,
#        -0.29411766, -0.28627452, -0.2784314 , -0.27058825, -0.2627451 ,
#        -0.25490198, -0.24705882, -0.23921569, -0.23137255, -0.22352941,
#        -0.21568628, -0.20784314, -0.2       , -0.19215687, -0.18431373,
#        -0.1764706 , -0.16862746, -0.16078432, -0.15294118, -0.14509805,
#        -0.13725491, -0.12941177, -0.12156863, -0.11372549, -0.10588235,
#        -0.09803922, -0.09019608, -0.08235294, -0.07450981, -0.06666667,
#        -0.05882353, -0.05098039, -0.04313726, -0.03529412, -0.02745098,
#        -0.01960784, -0.01176471, -0.00392157,  0.00392157,  0.01176471,
#         0.01960784,  0.02745098,  0.03529412,  0.04313726,  0.05098039,
#         0.05882353,  0.06666667,  0.07450981,  0.08235294,  0.09019608,
#         0.09803922,  0.10588235,  0.11372549,  0.12156863,  0.12941177,
#         0.13725491,  0.14509805,  0.15294118,  0.16078432,  0.16862746,
#         0.1764706 ,  0.18431373,  0.19215687,  0.2       ,  0.20784314,
#         0.21568628,  0.22352941,  0.23137255,  0.23921569,  0.24705882,
#         0.25490198,  0.2627451 ,  0.27058825,  0.2784314 ,  0.28627452,
#         0.29411766,  0.3019608 ,  0.30980393,  0.31764707,  0.3254902 ,
#         0.33333334,  0.34117648,  0.34901962,  0.35686275,  0.3647059 ,
#         0.37254903,  0.38039216,  0.3882353 ,  0.39607844,  0.40392157,
#         0.4117647 ,  0.41960785,  0.42745098,  0.43529412,  0.44313726,
#         0.4509804 ,  0.45882353,  0.46666667,  0.4745098 ,  0.48235294,
#         0.49019608,  0.49803922,  0.5058824 ,  0.5137255 ,  0.52156866,
#         0.5294118 ,  0.5372549 ,  0.54509807,  0.5529412 ,  0.56078434,
#         0.5686275 ,  0.5764706 ,  0.58431375,  0.5921569 ,  0.6       ,
#         0.60784316,  0.6156863 ,  0.62352943,  0.6313726 ,  0.6392157 ,
#         0.64705884,  0.654902  ,  0.6627451 ,  0.67058825,  0.6784314 ,
#         0.6862745 ,  0.69411767,  0.7019608 ,  0.70980394,  0.7176471 ,
#         0.7254902 ,  0.73333335,  0.7411765 ,  0.7490196 ,  0.75686276,
#         0.7647059 ,  0.77254903,  0.78039217,  0.7882353 ,  0.79607844,
#         0.8039216 ,  0.8117647 ,  0.81960785,  0.827451  ,  0.8352941 ,
#         0.84313726,  0.8509804 ,  0.85882354,  0.8666667 ,  0.8745098 ,
#         0.88235295,  0.8901961 ,  0.8980392 ,  0.90588236,  0.9137255 ,
#         0.92156863,  0.92941177,  0.9372549 ,  0.94509804,  0.9529412 ,
#         0.9607843 ,  0.96862745,  0.9764706 ,  0.9843137 ,  0.99215686,
#         1.        ], dtype=float32)

# %%
# box = [x,y,w,h] - >[x1,y1,x2,y2]
def get_iou(box1,box2):
    """
    Arg:
    box = (x, y, w, h)
    
    return: iou
    """
    
    box1 = [box1[0]-box1[2]/2,box1[1]-box1[3]/2,
            box1[0]+box1[2]/2,box1[1]+box1[3]/2]
    box2 = [box2[0]-box2[2]/2,box2[1]-box2[3]/2,
            box2[0]+box2[2]/2,box2[1]+box2[3]/2]
    
    intersection_x1 = max(box1[0],box2[0])
    intersection_y1 = max(box1[1],box2[1])
    intersection_x2 = min(box1[2],box2[2])
    intersection_y2 = min(box1[3],box2[3])
    
    iou = 0
    intersection_w = intersection_x2-intersection_x1
    intersection_h = intersection_y2-intersection_y1
    if(intersection_w <= 0 or intersection_h <= 0):
        return iou
    else:
        box1_w =  box1[2] - box1[0]
        box1_h =  box1[3] - box1[1]
        
        box2_w =  box2[2] - box2[0]
        box2_h =  box2[3] - box2[1]
        
        box1_size = box1_w * box1_h
        box2_size = box2_w * box2_h
        
        intersection_size = intersection_w * intersection_h
        union_size = box1_size + box2_size - intersection_size
        
        iou = intersection_size/union_size
        return iou
